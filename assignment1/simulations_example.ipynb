# %%
# %matplotlib inline

# %% [markdown]
# ## Simulation 1

# %%
import random
a,b,c,d = [random.randint(5, 50) for i in range(4)]
at,bt,ct,dt = [random.randint(20, 100) for i in range(4)]

# %%
import simulations
from visualization import plot_simulation

# %%
time_ms, vm, n, m, h, inj_array = simulations.simulation1(a,at,b,bt,c,ct,d,dt)
fig=plot_simulation(time_ms, vm, n, m, h, inj_array, title='Simulation 1')

# %% [markdown]
# ## Simulation 2

# %%
a,b = random.randint(50, 200), random.randint(50, 200)

# %%
time_ms, vm, n, m, h, inj_array = simulations.simulation2(a,b)
fig=plot_simulation(time_ms, vm, n, m, h, inj_array, title='Simulation 2')

# %%
a,b = random.randint(50, 200), random.randint(50, 200)

# %%
time_ms, vm, n, m, h, inj_array = simulations.simulation2(a,b)
fig=plot_simulation(time_ms, vm, n, m, h, inj_array, title='Simulation 2')
